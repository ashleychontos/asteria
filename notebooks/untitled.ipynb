# %%
from utils import *

# %%
ensemble_plot_teff()
# Out:
# teff~[3200,3300]; logg~[3.500000,3.600000]; n=0
# teff~[3200,3300]; logg~[3.600000,3.700000]; n=0
# teff~[3200,3300]; logg~[3.700000,3.800000]; n=0
# teff~[3200,3300]; logg~[3.800000,3.900000]; n=0
# teff~[3200,3300]; logg~[3.900000,4.000000]; n=0
# teff~[3200,3300]; logg~[4.000000,4.100000]; n=0
# teff~[3200,3300]; logg~[4.100000,4.200000]; n=0
# teff~[3200,3300]; logg~[4.200000,4.300000]; n=0
# teff~[3200,3300]; logg~[4.300000,4.400000]; n=0
# teff~[3200,3300]; logg~[4.400000,4.500000]; n=0
# teff~[3200,3300]; logg~[4.500000,4.600000]; n=0
# teff~[3200,3300]; logg~[4.600000,4.700000]; n=1
# teff~[3200,3300]; logg~[4.700000,4.800000]; n=0
# teff~[3200,3300]; logg~[4.800000,4.900000]; n=0
# teff~[3200,3300]; logg~[4.900000,5.000000]; n=0
# teff~[3200,3300]; logg~[5.000000,5.100000]; n=34
# teff~[3200,3300]; logg~[5.100000,5.200000]; n=9
# teff~[3300,3400]; logg~[3.500000,3.600000]; n=0
# teff~[3300,3400]; logg~[3.600000,3.700000]; n=0
# ...
